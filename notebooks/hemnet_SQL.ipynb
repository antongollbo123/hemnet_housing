# %%
import sqlite3 as db
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Anton/Documents/Anton_Gollbo/Skolarbete/projects/Hemnet_Housing/data/UNFINISHED_yelp_df_CLEANED2.csv")
df2 = pd.read_csv("C:/Users/Anton/Documents/Anton_Gollbo/Skolarbete/projects/Hemnet_Housing/data/hemnet_housing_yelp_csv.csv")

df = df.append(df2)

df.drop_duplicates()
df.to_csv("hemnet_housing_yelp.csv")

# %%
path = "C:/Users/Anton/Documents/Anton_Gollbo/Skolarbete/projects/Hemnet_Housing/data"

conn = db.connect(f"{path}/hemnet_database.db")
c = conn.cursor()

c.execute("CREATE TABLE housing_objects (id INTEGER PRIMARY KEY, adress NVARCHAR(100), fee INTEGER, features )")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cfeffbcd8111> in <module>
# ----> 1 strang = (f"{path}\hemnet_database.db")
#
# NameError: name 'path' is not defined

# %%
df
# Out:
#                      adress   fee  features  sale_price          sold_date  \
# 0              frejgatan 50  2391       1.0     6450000    15 januari 2022
# 1           rådmansgatan 86  2021       4.0     7200000    15 januari 2022
# 2      sankt eriksgatan 109   436       2.0     3150000    14 januari 2022
# 3              torsgatan 58  1733       2.0     3435000    14 januari 2022
# 4                torsplan 8  3950       3.0    10000000    14 januari 2022
# ...                     ...   ...       ...         ...                ...
# 10471      kammakargatan 70  1169       NaN     2800000       19 mars 2013
# 10472         olofsgatan 18   917       NaN     2360000   28 februari 2013
# 10473   regeringsgatan 70 d  3231       NaN     3600000   17 februari 2013
# 10474     drottninggatan 80  2647       NaN     3250000    22 januari 2013
# 10475     klara tvärgränd 5  2683       NaN     2725000    10 januari 2013
#
# ...

# %%
df.drop_duplicates()
# Out:
#                      adress   fee  features  sale_price          sold_date  \
# 0              frejgatan 50  2391       1.0     6450000    15 januari 2022
# 1           rådmansgatan 86  2021       4.0     7200000    15 januari 2022
# 2      sankt eriksgatan 109   436       2.0     3150000    14 januari 2022
# 3              torsgatan 58  1733       2.0     3435000    14 januari 2022
# 4                torsplan 8  3950       3.0    10000000    14 januari 2022
# ...                     ...   ...       ...         ...                ...
# 10471      kammakargatan 70  1169       NaN     2800000       19 mars 2013
# 10472         olofsgatan 18   917       NaN     2360000   28 februari 2013
# 10473   regeringsgatan 70 d  3231       NaN     3600000   17 februari 2013
# 10474     drottninggatan 80  2647       NaN     3250000    22 januari 2013
# 10475     klara tvärgränd 5  2683       NaN     2725000    10 januari 2013
#
# ...
